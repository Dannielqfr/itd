# %%
import numpy as np
import matplotlib.pyplot as plt
from statistics import mode
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
dataMaterial = pd.read_excel("./../data/Mayo31.xls",sheet_name="Base por material")
dataLector = pd.read_excel("./../data/Mayo31.xls",sheet_name="Base por lector")

# %% [markdown]
# # LIMPIEZA Y TRANFORMACION DE DATOS

# %% [markdown]
# ## Initial Validations

# %%
required_columns = [    
    'Antiguedad Cedente',
    'Identificador del operador cedente',
    'Cantidad de días de antiguedad',
    'Modalidad segmento del operador cedente',
    'Descripción operador cedente',
    'Fecha desde que el cliente estuvo en operador cedente',
  
    'Modalidad de venta',
    'Claro TV',
    'Internet Fija',
    'Telefonía Fija',
    
    'Tipo documento del vendedor',
    'DNI del dueño de multimarca',
    'Número de documento del vendedor',
    'Flag Login Vendedor',
    'Fecha Registro del dueño del multimarca',
    
    'Mes',
    'Fecha de venta',
    'Identificador del Chip',
    'Serie del lector biométrico móvil',
    'Número de telefono',
    'Flag Recarga',
    'Tipo de operación de venta',
    'Modalidad segmento de venta',
    'Descipción del plan',
    'Número del pedido rerlacionado a la venta',
    'Número de evaluación crediticia',
    'Número de la orden de trabajo',
    'Tipo venta C-CHIP/P-Pack',
    'Identificador del equipo (IMEI)',
    
    'Aplicativo donde se realizó la venta',
    'Canal del punto de venta del material',
    'Plataforma',
    
    'Región asociado al punto de venta del chip',
    'Dpto asociado al punto de venta del chip',
    
    'Razón social del dueño (LECTOR)',
    'RUC del dueño al que se despaño el lector biométrico móvil',
    'Razón social del dueño del chip que realizó la venta (MATERIAL)',
    'RUC del dueño del chip que realizó la venta',
    'Descripción del punto de venta del material',
    'Código del punto de venta del material',

    'Tipo de operación del biométrico',
    'Tipo Val Biométrica',
    'Tipo Venta Biométrico',
    'Usuario de Biometría "Biomovil"',
    'Venta Realizada Por',
]

columnas_faltantes = [col for col in required_columns if col not in dataMaterial.columns]

if columnas_faltantes:
    print(f"Las siguientes columnas faltan en el DataFrame: {columnas_faltantes}")
else:
    print("Todas las columnas requeridas están presentes.")
# Out:
# Todas las columnas requeridas están presentes.

# %%
nulo1 = dataMaterial['Aplicativo donde se realizó la venta'].isna().sum()
nulo2 = dataMaterial['Canal del punto de venta del material'].isna().sum()
nulo3 = dataMaterial['Descripción del punto de venta del material'].isna().sum()
nulo4 = dataMaterial['Código del punto de venta del material'].isna().sum()
nulo5 = dataMaterial['Dpto asociado al punto de venta del chip'].isna().sum()
nulo6 = dataMaterial['Mes'].isna().sum()
nulo7 = dataMaterial['Modalidad segmento de venta'].isna().sum()
nulo8 = dataMaterial['Tipo de operación de venta'].isna().sum()
nulo9 = dataMaterial['Región asociado al punto de venta del chip'].isna().sum()
nulo10 = dataMaterial['Tipo de operación del biométrico'].isna().sum()
nulo11 = dataMaterial['Tipo Val Biométrica'].isna().sum()
nulo12 = dataMaterial['Tipo Venta Biométrico'].isna().sum()
nulo13 = dataMaterial['Usuario de Biometría "Biomovil"'].isna().sum()
nulo14 = dataMaterial['Venta Realizada Por'].isna().sum()

print(nulo1+nulo2+nulo3+nulo4+nulo5+nulo6+nulo7+nulo8+nulo9+nulo10+nulo11+nulo12+nulo13+nulo14)
# Out:
# 0

# %% [markdown]
# ## Manage columns

# %%
dataMaterial.rename(columns={
    'Antiguedad Cedente':'CEDENT_ISMORETHAN90DAYS',
    'Identificador del operador cedente':'CEDENT_CODOPERADOR',
    'Cantidad de días de antiguedad':'CEDENT_DIASANTIGUEDAD',
    'Modalidad segmento del operador cedente':'CEDENT_PRODUCT',
    'Descripción operador cedente':'CEDENT_OPERATOR',
    'Fecha desde que el cliente estuvo en operador cedente':'CEDENT_DATE',
    
    'Modalidad de venta':'PLAY',
    'Claro TV':'FIJA_TV',
    'Internet Fija':'FIJA_INTERNET',
    'Telefonía Fija':'FIJA_PHONE',

    'Tipo documento del vendedor':'DOCUMENT_TYPE_SELLER',
    'DNI del dueño de multimarca':'DNI_MM',
    'Número de documento del vendedor':'DOCUMENT_NRO_SELLER',
    'Flag Login Vendedor':'FLAG_LOGIN_SELLER',
    'Fecha Registro del dueño del multimarca':'FECHA_REGISTER_MM',
    
    'Mes':'PERIOD',
    'Fecha de venta':'FECHA_VENTA',
    'Identificador del Chip':'CHIP',
    'Serie del lector biométrico móvil':'BIOMETRIC_SERIE',
    'Número de telefono':'PHONE_NUMBER',
    'Flag Recarga':'RECHARGE',
    'Tipo de operación de venta':'OPE_VENTA',
    'Modalidad segmento de venta':'PRODUCT',
    'Descipción del plan':'PLAN_DESCRIPTION',
    'Número del pedido rerlacionado a la venta':'CONTRATO',
    'Número de evaluación crediticia':'SEC',
    'Número de la orden de trabajo':'SOT',
    'Tipo venta C-CHIP/P-Pack':'TIPO_VENTA',
    'Identificador del equipo (IMEI)':'IMEI',
    
    'Aplicativo donde se realizó la venta':'APP',
    'Canal del punto de venta del material':'CHANNEL',
    'Plataforma':'PLATFORM',

    'Región asociado al punto de venta del chip':'REGION',
    'Dpto asociado al punto de venta del chip':'DEPARTMENT_CHIP',
    
    'Razón social del dueño (LECTOR)':'BIOMETRIC_RAZONSOCIAL',
    'RUC del dueño al que se despaño el lector biométrico móvil':'BIOMETRIC_RUC',
    'Razón social del dueño del chip que realizó la venta (MATERIAL)':'CHIP_RAZONSOCIAL',
    'RUC del dueño del chip que realizó la venta':'CHIP_RUC',
    'Descripción del punto de venta del material':'DAC_CHIP',
    'Código del punto de venta del material':'COD_PDV',
    
    'Tipo de operación del biométrico':'BIOMETRIC_OPE',
    'Tipo Val Biométrica':'BIOMETRIC_VALIDATION',
    'Tipo Venta Biométrico':'BIOMETRIC_OWNER',
    'Usuario de Biometría "Biomovil"':'USER',
    'Venta Realizada Por':'DONE_BY'
}, inplace=True)

# %%
index = ['CEDENT_ISMORETHAN90DAYS','CEDENT_CODOPERADOR','CEDENT_DIASANTIGUEDAD','CEDENT_PRODUCT','CEDENT_OPERATOR','CEDENT_DATE',
         'PLAY','FIJA_TV','FIJA_INTERNET','FIJA_PHONE','DOCUMENT_TYPE_SELLER','DNI_MM','DOCUMENT_NRO_SELLER','FLAG_LOGIN_SELLER',
         'FECHA_REGISTER_MM','PERIOD','FECHA_VENTA','CHIP','BIOMETRIC_SERIE','PHONE_NUMBER','RECHARGE','OPE_VENTA','PRODUCT','PLAN_DESCRIPTION',
         'CONTRATO','SEC','SOT','TIPO_VENTA','IMEI','APP','CHANNEL','PLATFORM','REGION','DEPARTMENT_CHIP','BIOMETRIC_RAZONSOCIAL','BIOMETRIC_RUC',
         'CHIP_RAZONSOCIAL','CHIP_RUC','DAC_CHIP','COD_PDV','BIOMETRIC_OPE','BIOMETRIC_VALIDATION','BIOMETRIC_OWNER','USER','DONE_BY']
dataMaterial = dataMaterial.reindex(columns=index)

# %% [markdown]
# ## ***`BOOLEAN`*** casting

# %%
dataMaterial = dataMaterial.astype({'FIJA_TV':'str','FIJA_INTERNET':'str','FIJA_PHONE':'str','FLAG_LOGIN_SELLER':'str','RECHARGE':'str'})

dataMaterial['FIJA_TV']=dataMaterial['FIJA_TV'].replace({'0':''},regex=True)
dataMaterial['FIJA_TV']=dataMaterial['FIJA_TV'].replace({'1':'True'},regex=True)

dataMaterial['FIJA_INTERNET']=dataMaterial['FIJA_INTERNET'].replace({'0':''},regex=True)
dataMaterial['FIJA_INTERNET']=dataMaterial['FIJA_INTERNET'].replace({'1':'True'},regex=True)

dataMaterial['FIJA_PHONE']=dataMaterial['FIJA_PHONE'].replace({'0':''},regex=True)
dataMaterial['FIJA_PHONE']=dataMaterial['FIJA_PHONE'].replace({'1':'True'},regex=True)

dataMaterial['FLAG_LOGIN_SELLER']=dataMaterial['FLAG_LOGIN_SELLER'].replace({'0':''},regex=True)
dataMaterial['FLAG_LOGIN_SELLER']=dataMaterial['FLAG_LOGIN_SELLER'].replace({'1':'True'},regex=True)

dataMaterial['RECHARGE']=dataMaterial['RECHARGE'].replace({'No':''},regex=True)
dataMaterial['RECHARGE']=dataMaterial['RECHARGE'].replace({'Si':'True'},regex=True)

dataMaterial = dataMaterial.astype({'FIJA_TV':'bool','FIJA_INTERNET':'bool','FIJA_PHONE':'bool','FLAG_LOGIN_SELLER':'bool','RECHARGE':'bool'})

# %% [markdown]
# ## ***``OBJECT``*** Casting

# %% [markdown]
# ### `CEDENT_ISMORETHAN90DAYS` `CEDENT_PRODUCT` `CEDENT_OPERATOR` `PLAY` `DOCUMENT_TYPE_SELLER` `DOCUMENT_NRO_SELLER` `BIOMETRIC_SERIE` `PLAN_DESCRIPTION` `TIPO_VENTA`

# %%
dataMaterial = dataMaterial.astype({
    'CEDENT_ISMORETHAN90DAYS':'str',
    'CEDENT_PRODUCT':'str',
    'CEDENT_OPERATOR':'str',
    'PLAY':'str',
    'DOCUMENT_TYPE_SELLER':'str',
    'DOCUMENT_NRO_SELLER':'str',
    'BIOMETRIC_SERIE':'str',
    'PLAN_DESCRIPTION':'str',
    'TIPO_VENTA':'str',
    'IMEI':'str',
    'CONTRATO':'str',
    'BIOMETRIC_RAZONSOCIAL':'str',
    'CHIP_RAZONSOCIAL':'str',
    'PLATFORM':'str',
})

dataMaterial['CEDENT_ISMORETHAN90DAYS']=dataMaterial['CEDENT_ISMORETHAN90DAYS'].replace({'nan':''},regex=True)
dataMaterial['CEDENT_PRODUCT']=dataMaterial['CEDENT_PRODUCT'].replace({'nan':''},regex=True)
dataMaterial['CEDENT_OPERATOR']=dataMaterial['CEDENT_OPERATOR'].replace({'nan':''},regex=True)
dataMaterial['PLAY']=dataMaterial['PLAY'].replace({'nan':''},regex=True)
dataMaterial['BIOMETRIC_SERIE']=dataMaterial['BIOMETRIC_SERIE'].replace({'nan':''},regex=True)
dataMaterial['PLAN_DESCRIPTION']=dataMaterial['PLAN_DESCRIPTION'].replace({'nan':''},regex=True)
dataMaterial['TIPO_VENTA']=dataMaterial['TIPO_VENTA'].replace({'C':'Chip'},regex=True)
dataMaterial['TIPO_VENTA']=dataMaterial['TIPO_VENTA'].replace({'P':'Pack'},regex=True)
dataMaterial['IMEI']=dataMaterial['IMEI'].replace({'nan':''},regex=True)
dataMaterial['BIOMETRIC_RAZONSOCIAL']=dataMaterial['BIOMETRIC_RAZONSOCIAL'].replace({'nan':''},regex=True)
dataMaterial['CHIP_RAZONSOCIAL']=dataMaterial['CHIP_RAZONSOCIAL'].replace({'nan':''},regex=True)
dataMaterial['PLATFORM']=dataMaterial['PLATFORM'].replace({'nan':''},regex=True)

# %% [markdown]
# ### `DNI_MM`

# %%
dataMaterial = dataMaterial.astype({'DNI_MM':'str'})

dataMaterial['DNI_MM']=dataMaterial['DNI_MM'].replace({'nan':'00000000'},regex=True)

dataMaterial['DNI_MM'] = dataMaterial['DNI_MM'].astype(float)
dataMaterial['DNI_MM'] = dataMaterial['DNI_MM'].round().astype(int)
dataMaterial['DNI_MM'] = dataMaterial['DNI_MM'].astype(str)
dataMaterial['DNI_MM'] = dataMaterial['DNI_MM'].str.zfill(8)
dataMaterial['DNI_MM']=dataMaterial['DNI_MM'].replace({'00000000':''},regex=True)

# %% [markdown]
# ### `CEDENT_CODOPERADOR` `SEC` `SOT`

# %%
dataMaterial['CEDENT_CODOPERADOR'] = dataMaterial['CEDENT_CODOPERADOR'].fillna(-1)
dataMaterial['CEDENT_CODOPERADOR'] = dataMaterial['CEDENT_CODOPERADOR'].round().astype(int)
dataMaterial['CEDENT_CODOPERADOR'] = dataMaterial['CEDENT_CODOPERADOR'].astype(str)
dataMaterial['CEDENT_CODOPERADOR'] = dataMaterial['CEDENT_CODOPERADOR'].replace({'-1':''},regex=True)

dataMaterial['SEC'] = dataMaterial['SEC'].fillna(-1)
dataMaterial['SEC'] = dataMaterial['SEC'].round().astype(int)
dataMaterial['SEC'] = dataMaterial['SEC'].astype(str)
dataMaterial['SEC'] = dataMaterial['SEC'].replace({'-1':''},regex=True)

dataMaterial['SOT'] = dataMaterial['SOT'].fillna(-1)
dataMaterial['SOT'] = dataMaterial['SOT'].round().astype(int)
dataMaterial['SOT'] = dataMaterial['SOT'].astype(str)
dataMaterial['SOT'] = dataMaterial['SOT'].replace({'-1':''},regex=True)

# %% [markdown]
# ### `RUC`

# %%
dataMaterial['BIOMETRIC_RUC'] = dataMaterial['BIOMETRIC_RUC'].fillna(-1)
dataMaterial['BIOMETRIC_RUC'] = dataMaterial['BIOMETRIC_RUC'].round().astype(np.int64)
dataMaterial['BIOMETRIC_RUC'] = dataMaterial['BIOMETRIC_RUC'].astype(str)
dataMaterial['BIOMETRIC_RUC'] = dataMaterial['BIOMETRIC_RUC'].replace({'-1':''},regex=True)

dataMaterial['CHIP_RUC'] = dataMaterial['CHIP_RUC'].fillna(-1)
dataMaterial['CHIP_RUC'] = dataMaterial['CHIP_RUC'].round().astype(np.int64)
dataMaterial['CHIP_RUC'] = dataMaterial['CHIP_RUC'].astype(str)
dataMaterial['CHIP_RUC'] = dataMaterial['CHIP_RUC'].replace({'-1':''},regex=True)

# %% [markdown]
# ### `PHONE_NUMBER`

# %%
dataMaterial['PHONE_NUMBER'] = dataMaterial['PHONE_NUMBER'].astype(float)
dataMaterial['PHONE_NUMBER'] = dataMaterial['PHONE_NUMBER'].round().astype(int)
dataMaterial['PHONE_NUMBER'] = dataMaterial['PHONE_NUMBER'].astype(str)
dataMaterial['PHONE_NUMBER'] = dataMaterial['PHONE_NUMBER'].str.zfill(9)
dataMaterial['PHONE_NUMBER'] = dataMaterial['PHONE_NUMBER'].replace({'999999998':'999999999'},regex=True)

# %% [markdown]
# ## ***`INT`*** Casting

# %% [markdown]
# ### `CHIP`

# %%
dataMaterial['CHIP'] = dataMaterial['CHIP'].fillna(0)
dataMaterial['CHIP'] = dataMaterial['CHIP'].round().astype(np.int64)

# %% [markdown]
# ### `CEDENT_DIASANTIGUEDAD`

# %%
dataMaterial['CEDENT_DIASANTIGUEDAD'] = dataMaterial['CEDENT_DIASANTIGUEDAD'].fillna(-1)
dataMaterial['CEDENT_DIASANTIGUEDAD'] = dataMaterial['CEDENT_DIASANTIGUEDAD'].round().astype(int)

# %% [markdown]
# ## ***`DATE`***

# %%
dataMaterial['FECHA_VENTA'] = pd.to_datetime(dataMaterial['FECHA_VENTA'],format='%Y/%m/%d')
dataMaterial['FECHA_VENTA'] = dataMaterial['FECHA_VENTA'].dt.strftime('%d/%m/%Y')

dataMaterial['FECHA_REGISTER_MM'] = pd.to_datetime(dataMaterial['FECHA_REGISTER_MM'],format='%Y/%m/%d')
dataMaterial['FECHA_REGISTER_MM'] = dataMaterial['FECHA_REGISTER_MM'].dt.strftime('%d/%m/%Y')

# CEDENT_DATE
dataMaterial['CEDENT_DATE'].replace('', pd.NaT)#, inplace=True)
dataMaterial['CEDENT_DATE'] = pd.to_datetime(dataMaterial['CEDENT_DATE'], format='%Y/%m/%d', errors='coerce')
dataMaterial['CEDENT_DATE'] = dataMaterial['CEDENT_DATE'].fillna(pd.Timestamp('2000-01-01'))
dataMaterial['CEDENT_DATE'] = dataMaterial['CEDENT_DATE'].dt.strftime('%d/%m/%Y')

# %% [markdown]
# Si CEDENT_DATE es menor que los demás CEDENT es porque no se ha validado los días de antiguedad (no aplica)

# %% [markdown]
# ## Validaciones

# %% [markdown]
# ### Valores nulos

# %%
print(dataMaterial['IMEI'].isna().sum())
# Out:
# 13685

# %% [markdown]
# ### Valores únicos

# %%
print(dataMaterial['BIOMETRIC_RAZONSOCIAL'].unique())
# Out:
# ['Tiptel S.A.C.' 'M.I.D. Servicios Generales E.I.R.L.'
#  'Pastrana Jimenez Mariluz Rocio' 'Rem Asociados S.A.C.' ''
#  'S & C Soluciones Integrales S.A.C.' 'Pisacom S.A.C' 'Huaytelcoms S.A.C.'
#  'Rc. Telecomunicaciones S.A.C.' 'Smartphone Peru S.A.C.'
#  'J&H Telekomunicaciones S.A.C.' 'Abcell Telecomunicaciones S.A.C'
#  'Mamvi Movil E.I.R.L.' 'Corporacion Jean Paul S.A.C.'
#  'Elias Vasquez Yeison Rildo' 'Contelsac Sociedad Anonima Cerrada'
#  'Megacell Telecomunicaciones S.A.C.' 'Mega Connection S.A.C.'
#  'Inversiones Solano E.I.R.L.' 'Akemitel Eirl'
#  'Solotell Comunicaciones S.A.C.' 'Electrovia Sociedad Anonima Cerrada'
#  'Nilton Cesar Silva Flores' 'Cellcom Peru S.A.C'
#  'Inversiones Ayelen Eirl' 'M & A Comunicaciones E.I.R.L.'
#  'Net Axxes S.A.C.' 'Cyctel S.A.C.' 'Grupo De Empresarios Jj S.A.C'
#  'Enfocado S.A.C.' 'Masservicios S.A.C.' 'Telsur Comunicaciones S.A.C.'
#  'Fava Telecomunicaciones Y Multiserv' 'Odj Telecomunicaciones S.A.C'
# ...

# %% [markdown]
# ### Sumar valores

# %%
print(dataMaterial['SOT'].sum())

# %% [markdown]
# ## Tablas

# %%
dataMaterial.isna().sum()
# Out:
# CEDENT_ISMORETHAN90DAYS    0
# CEDENT_CODOPERADOR         0
# CEDENT_DIASANTIGUEDAD      0
# CEDENT_PRODUCT             0
# CEDENT_OPERATOR            0
# CEDENT_DATE                0
# PLAY                       0
# FIJA_TV                    0
# FIJA_INTERNET              0
# FIJA_PHONE                 0
# DOCUMENT_TYPE_SELLER       0
# DNI_MM                     0
# DOCUMENT_NRO_SELLER        0
# FLAG_LOGIN_SELLER          0
# FECHA_REGISTER_MM          0
# PERIOD                     0
# FECHA_VENTA                0
# CHIP                       0
# BIOMETRIC_SERIE            0
# PHONE_NUMBER               0
# RECHARGE                   0
# OPE_VENTA                  0
# PRODUCT                    0
# PLAN_DESCRIPTION           0
# CONTRATO                   0
# SEC                        0
# SOT                        0
# TIPO_VENTA                 0
# IMEI                       0
# APP                        0
# CHANNEL                    0
# PLATFORM                   0
# ...

# %%
dataMaterial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13688 entries, 0 to 13687
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CEDENT_ISMORETHAN90DAYS  13688 non-null  object
#  1   CEDENT_CODOPERADOR       13688 non-null  object
#  2   CEDENT_DIASANTIGUEDAD    13688 non-null  int32
#  3   CEDENT_PRODUCT           13688 non-null  object
#  4   CEDENT_OPERATOR          13688 non-null  object
#  5   CEDENT_DATE              13688 non-null  object
#  6   PLAY                     13688 non-null  object
#  7   FIJA_TV                  13688 non-null  bool
#  8   FIJA_INTERNET            13688 non-null  bool
#  9   FIJA_PHONE               13688 non-null  bool
#  10  DOCUMENT_TYPE_SELLER     13688 non-null  object
#  11  DNI_MM                   13688 non-null  object
#  12  DOCUMENT_NRO_SELLER      13688 non-null  object
#  13  FLAG_LOGIN_SELLER        13688 non-null  bool
# ...

# %%
dataMaterial.iloc[50:80]
# Out:
#    CEDENT_ISMORETHAN90DAYS CEDENT_CODOPERADOR  CEDENT_DIASANTIGUEDAD  \
# 50                                                                -1
# 51                                                                -1
# 52                                                                -1
# 53                                                                -1
# 54                                                                -1
# 55                                                                -1
# 56                                                                -1
# 57                                                                -1
# 58                                                                -1
# 59                                                                -1
# 60                                                                -1
# 61                                                                -1
# 62                                                                -1
# ...

# %%
dataMaterial['PHONE_NUMBER'].iloc[1:10]
# Out:
# 1   913001387
# 2   900084924
# 3   920391699
# 4   900084924
# 5   920391699
# 6           0
# 7           0
# 8           0
# 9           0
# Name: PHONE_NUMBER, dtype: float64

# %% [markdown]
# # PROCESAMIENTO DE DATOS

# %%
def convertir_fecha(fecha):
    day, month, year = fecha.split('/')
    return f'{year}-{month}-{day}'

# %%
days = dataMaterial['FECHA_VENTA']
unique_days = days.drop_duplicates()

composed_days = []
light = []

for i,row in unique_days.items():
    light = dataMaterial['FECHA_VENTA']==row
    final = dataMaterial[light].shape
    composed_days.append([row,final[0]])

np_composed_days = np.array(composed_days) # np_arr
np_days_qnt = np_composed_days[:,1] # np_arr string
np_arr_qnt = np_days_qnt.astype(np.int32) # np_arr int

def convertir_fecha(fecha):
    day, month, year = fecha.split('/')
    return f'{year}-{month}-{day}'

np_composed_days_date = np.array([np.datetime64(convertir_fecha(fecha)) for fecha in np_composed_days[:, 0]])
sorted_index = np.argsort(np_composed_days_date)
np_composed_days_date_sorted = np_composed_days_date[sorted_index]
np_composed_days_qnt_sorted = np_arr_qnt[sorted_index]

plt.figure(figsize=(10,5))
plt.plot(np_composed_days_date_sorted,np_composed_days_qnt_sorted, marker='o')
plt.xlabel('Fechas')
plt.ylabel('Cantidades')
plt.title('PRODUCCION MAYO 2024')

plt.grid(True)
plt.xticks(rotation=90, fontsize=7)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Configuracion Final

# %%
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')
pd.reset_option('display.max_colwidth')
